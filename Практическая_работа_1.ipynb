# %% [markdown]
# <a href="https://colab.research.google.com/github/chaosdara/-/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
a=5
b=2
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 7
# 3
# 10
# 2.5

# %%
a=5
b=2
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
# Out:
# True
# False
# False
# True

# %%
print("Hello? world! My name Наталья Ульяницкая")
x=input("введите число: ")
print("Вы ввели число : "+x)
# Out:
# Hello? world! My name Наталья Ульяницкая
# введите число: 5
# Вы ввели число : 5
