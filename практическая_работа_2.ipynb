# %% [markdown]
# <a href="https://colab.research.google.com/github/chaosdara/-/blob/main/%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.layers import Dense

c = np.array([-40,-10,0,8,15,22,38])
f = np.array([-40,14,32,46,59,72,100])
model = keras.Sequential()
model.add(Dense(units=1, input_shape=(1,),activation='linear'))
model.compile(loss='mean_squared_error',optimizers=keras.optimizer.Adam(0.1))
history=model.fit(c,f,epochs=500,verbose=0)
print("Обучение завершено")
plt.plot(history.history['loss'])
plt.grid(True)
plt.show()
print(model.predict([100]))
print(model.get_weights())
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /tmp/ipython-input-198201468.py in <cell line: 0>()
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
# ----> 6 from tensorflow import keras
#       7 from tensorflow.keras.layers import Dense
#       8
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/__init__.py in <module>
#     430   _kernel_dir = _os.path.join(_tf_dir, "core", "kernels")
#     431   if _os.path.exists(_kernel_dir):
# --> 432     _ll.load_library(_kernel_dir)
#     433
#     434   # Load third party dynamic kernels.
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/load_library.py in load_library(library_location)
#     149
#     150     for lib in kernel_libraries:
# --> 151       py_tf.TF_LoadLibrary(lib)
#     152
#     153   else:
#
# ...
